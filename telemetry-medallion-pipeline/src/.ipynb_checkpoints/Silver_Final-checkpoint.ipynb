# %%
import pandas as pd
import sqlite3
import os
import re

def process_agent_team_list(base_path):
    # Define data layer paths (Medallion architecture)
    # Bronze = raw ingestion layer, Silver = cleaned/standardised layer
    source_path = os.path.join(base_path, "Bronze")   # Raw source files
    silver_path = os.path.join(base_path, "Silver")   # Cleaned, structured outputs

    # --------------------------------------------------------------------------------
    # Identify all relevant input files in the Bronze layer
    # Only files matching expected naming convention are processed
    # Expected naming convention: "Agents Team List YYYYMMDD.xlsx"
    all_files = [
        f for f in os.listdir(source_path)
        if f.startswith("Agents Team List") and f.endswith(".xlsx")
    ]

    # Process each file independently (batch-style ingestion)
    # Each file is treated as a snapshot of data at a point in time
    for file_name in all_files:

        # Extract snapshot date from filename (used for versioning output files)
        # This assumes YYYYMMDD is always present in filename
        file_date_str = re.search(r"\d{8}", file_name).group()

        print(f"Processing: {file_name}")

        # Build full file path and load Excel file into pandas DataFrame
        file_path = os.path.join(source_path, file_name)
        dim_df = pd.read_excel(file_path)

        # --------------------------------------------------------------------------------
        # DATA CLEANSING & STANDARDISATION STEP
        # Ensures consistency before applying business logic

        # Convert date columns to datetime format
        # errors='coerce' ensures invalid values become NaT instead of crashing pipeline
        dim_df["date_from"] = pd.to_datetime(dim_df["date_from"], dayfirst=True, errors="coerce")
        dim_df["date_to"] = pd.to_datetime(dim_df["date_to"], dayfirst=True, errors="coerce")

        # Flag current (active) records where end date is missing
        # 1 = active record, 0 = historical record
        dim_df["flag_current"] = dim_df["date_to"].isna().astype(int)

        # Handle multiple records starting on same date per employee
        # cumcount creates versioning within same partition
        dim_df["version_id"] = dim_df.groupby(["employee_id", "date_from"]).cumcount()

        # --------------------------------------------------------------------------------
        # Prepare dates for SQL processing (SQLite limitation workaround)
        # SQLite handles string dates more reliably for window functions

        dim_df["date_from"] = dim_df["date_from"].dt.strftime("%Y-%m-%d")
        dim_df["date_to"] = dim_df["date_to"].dt.strftime("%Y-%m-%d")

        # Replace null end dates with a far-future sentinel value
        # Used to represent open-ended employment records
        dim_df["date_to"] = dim_df["date_to"].fillna("2099-12-31")

        # TODO (data quality improvements for future iteration):
        # - Handle missing employee_id values
        # - Flag invalid or corrupt records
        # - Assign temporary surrogate IDs if needed
        # - Exclude invalid records in Gold layer aggregation

        # --------------------------------------------------------------------------------
        # SQLITE ENGINE (in-memory transformation layer)
        # Used to apply SQL window functions not easily available in pandas

        conn = sqlite3.connect(":memory:")

        # Load DataFrame into in-memory SQL table for processing
        dim_df.to_sql("dim_df", conn, index=False, if_exists="replace")

        # --------------------------------------------------------------------------------
        # WINDOW FUNCTION LOGIC
        # Ensures no overlapping date ranges per employee (SCD Type 2 cleanup)

        query = """
        SELECT
            employee_id,
            employee_name,
            date_from,
            CASE
                WHEN next_date_from IS NOT NULL THEN date(next_date_from, '-1 day')
                ELSE date_to
            END as date_to,
            region,
            manager,
            flag_current
        FROM (
            SELECT
                *,
                LEAD(date_from) OVER (
                    PARTITION BY employee_id 
                    ORDER BY date_from, version_id
                ) as next_date_from
            FROM dim_df
        )
        """

        # Execute SQL transformation and bring result back into pandas
        dim_clean = pd.read_sql(query, conn)

        # --------------------------------------------------------------------------------
        # DERIVED FIELDS (post-SQL enrichment)

        # Create standardized key for matching, deduplication, and joins
        # Normalises whitespace and case sensitivity
        dim_clean["name_key"] = (
            dim_clean["employee_name"]
            .astype(str)
            .str.strip()
            .str.upper()
        )

        # --------------------------------------------------------------------------------
        # SURROGATE KEY GENERATION (Dimension table design pattern)

        # Sort ensures deterministic surrogate key assignment
        dim_clean = dim_clean.sort_values(["employee_id", "date_from"]).reset_index(drop=True)

        # Assign sequential surrogate key
        dim_clean["sk_employee"] = dim_clean.index + 1

        # Reorder columns so surrogate key is first (common data warehousing convention)
        dim_clean = dim_clean[["sk_employee"] + [c for c in dim_clean.columns if c != "sk_employee"]]

        # --------------------------------------------------------------------------------
        # OUTPUT TO SILVER LAYER

        # File naming includes snapshot date for historical tracking
        output_file = f"dim_clean_{file_date_str}.csv"
        full_path = os.path.join(silver_path, output_file)

        # Persist cleaned dataset to Silver layer
        dim_clean.to_csv(full_path, index=False)

        print(f"Saved: {full_path}")

# %%
base_path = r"C:\CallAgents"
process_agent_team_list(base_path)

# %%
import pandas as pd
import os
import numpy as np
from pandasql import sqldf

def process_telephony_pipeline(base_path):

    # --------------------------------------------------------------------------------
    # SQL ENGINE SETUP
    # --------------------------------------------------------------------------------
    # pandasql is used to enable SQL-style queries on pandas DataFrames.
    # This is particularly useful for NON-EQUI JOINS (e.g., BETWEEN conditions),
    # which are not natively supported in pandas merge operations.
    pysqldf = lambda q: sqldf(q, globals())

    # --------------------------------------------------------------------------------
    # DIRECTORY CONFIGURATION (Medallion Architecture)
    # --------------------------------------------------------------------------------
    # Bronze = raw ingested data
    # Silver = cleaned + enriched + conformed data
    source_path = os.path.join(base_path, "Bronze")
    silver_path = os.path.join(base_path, "Silver")

    # --------------------------------------------------------------------------------
    # 1. LOAD LATEST DIMENSION TABLE (Agent Master Data)
    # --------------------------------------------------------------------------------
    # This dimension table contains surrogate keys (sk_employee)
    # used for consistent identity tracking across time periods (SCD concept)

    dim_files = [f for f in os.listdir(silver_path) if f.startswith("dim_clean") and f.endswith(".csv")]

    if len(dim_files) > 0:
        # Select most recently modified dimension file
        latest_dim_file = max(dim_files, key=lambda x: os.path.getmtime(os.path.join(silver_path, x)))
        dim_clean = pd.read_csv(os.path.join(silver_path, latest_dim_file))
        
        # Standardise date formats for SQL-based range comparisons
        dim_clean["date_from"] = pd.to_datetime(dim_clean["date_from"]).dt.strftime('%Y-%m-%d')
        dim_clean["date_to"] = pd.to_datetime(dim_clean["date_to"]).dt.strftime('%Y-%m-%d')
        
        # Normalised matching key (used for joining with fact data)
        dim_clean["name_key"] = dim_clean["employee_name"].astype(str).str.strip().str.upper()
    else:
        # If dimension is missing, surrogate key assignment cannot be performed
        dim_clean = None
        print("CRITICAL: No Dimension file found. Surrogate Keys (sk) cannot be assigned.")

    # --------------------------------------------------------------------------------
    # 2. IDENTIFY RAW TELEPHONY FILES (FACT DATA SOURCE)
    # --------------------------------------------------------------------------------
    # These files contain transactional call/telephony data
    all_files = [f for f in os.listdir(source_path) if f.startswith("Telephony") and f.endswith(".csv")]

    # --------------------------------------------------------------------------------
    # 3. MAIN PROCESSING LOOP (Batch Ingestion per File)
    # --------------------------------------------------------------------------------
    for file_name in all_files:
        file_path = os.path.join(source_path, file_name)
        
        # Extract YYYYMMDD from filename for versioning and traceability
        digits = "".join([c for c in file_name if c.isdigit()])
        file_date_str = digits[:8]
        
        print(f"Processing: {file_name}")

        # Load raw telephony data
        df = pd.read_csv(file_path)

        # --------------------------------------------------------------------------------
        # METADATA ENRICHMENT + DATA CLEANING
        # --------------------------------------------------------------------------------

        # File-level ingestion timestamp (used for auditability)
        df["file_date"] = pd.to_datetime(file_date_str, format="%Y%m%d")
        df["load_timestamp"] = pd.Timestamp.now()

        # Standardise call date column
        df["date"] = pd.to_datetime(df["date"], dayfirst=True, errors="coerce")
        df["date_sql"] = df["date"].dt.strftime('%Y-%m-%d')

        # Data quality flags
        # flag_dateWrong = invalid/unparseable dates
        # flag_nameWrong = missing agent names
        df["flag_dateWrong"] = df["date"].isna().astype(int)
        df["flag_nameWrong"] = df["agent"].isna().astype(int)

        # Handle missing agent values
        df["agent"] = df["agent"].fillna("NONE#").astype(str)

        # Fill missing numeric metrics with 0 (assumes absence = zero activity)
        numeric_cols = df.select_dtypes(include=["number"]).columns
        df[numeric_cols] = df[numeric_cols].fillna(0)

        # --------------------------------------------------------------------------------
        # 4. SURROGATE KEY (SK) LOOKUP - DIMENSION JOIN
        # --------------------------------------------------------------------------------
        # This step maps raw agent names to structured dimension keys (sk_employee)
        # using a temporal join (validity range matching)

        if dim_clean is not None:
            # Standardised join key (case/space insensitive matching)
            df["name_key"] = df["agent"].astype(str).str.strip().str.upper()

            # SQL-based non-equi join:
            # - Matches on name_key
            # - Ensures fact date falls within valid dimension date range
            query = """
            SELECT
                t.*,
                dim.employee_id,
                dim.sk_employee
            FROM df t
            LEFT JOIN dim_clean dim ON t.name_key = dim.name_key
                AND t.date_sql BETWEEN dim.date_from AND dim.date_to
            """

            # Execute SQL join (requires explicit variable context for pandasql)
            df = sqldf(query, {"df": df, "dim_clean": dim_clean})

        # --------------------------------------------------------------------------------
        # 5. FINAL FORMATTING (OUTPUT STANDARDISATION)
        # --------------------------------------------------------------------------------

        # Convert dates back into human-readable format for downstream users
        df["date"] = pd.to_datetime(df["date"]).dt.strftime('%d/%m/%Y')
        df["file_date"] = pd.to_datetime(df["file_date"]).dt.strftime('%d/%m/%Y')

        # Remove SQL helper column (no longer required)
        if "date_sql" in df.columns:
            df = df.drop(columns=["date_sql"])

        # --------------------------------------------------------------------------------
        # OUTPUT TO SILVER LAYER
        # --------------------------------------------------------------------------------
        # Each file is versioned using its source date for traceability
        output_file = f"Telephony_{file_date_str}.csv"
        output_path = os.path.join(silver_path, output_file)

        df.to_csv(output_path, index=False)
        print(f"Successfully saved with Surrogate Keys: {output_file}")

# %%
# Example execution
base_path = r"C:\CallAgents"
process_telephony_pipeline(base_path)

# %%
import pandas as pd
import os
from datetime import datetime
from pandasql import sqldf

def process_schedules_pipeline(base_path):

    # --------------------------------------------------------------------------------
    # SQL ENGINE SETUP
    # --------------------------------------------------------------------------------
    # pandasql is used to execute SQL queries directly on pandas DataFrames.
    # This is particularly useful for complex join logic (e.g., range joins / BETWEEN)
    # which are not efficiently supported using standard pandas merge operations.
    pysqldf = lambda q: sqldf(q, globals())

    # --------------------------------------------------------------------------------
    # PATH CONFIGURATION (Medallion Architecture)
    # --------------------------------------------------------------------------------
    # Bronze = raw input data (unvalidated schedules)
    # Silver = cleaned, de-duplicated, business-ready dataset
    source_path = os.path.join(base_path, "Bronze")
    silver_path = os.path.join(base_path, "Silver")

    # --------------------------------------------------------------------------------
    # 1. LOAD LATEST DIMENSION TABLE (Employee Master Data)
    # --------------------------------------------------------------------------------
    # This dimension table provides surrogate keys (sk_employee)
    # ensuring consistent employee identity across time (SCD Type 2 logic)

    dim_files = [f for f in os.listdir(silver_path) if f.startswith("dim_clean") and f.endswith(".csv")]

    if len(dim_files) > 0:
        # Select most recently updated dimension file
        latest_dim_file = max(dim_files, key=lambda x: os.path.getmtime(os.path.join(silver_path, x)))
        dim_clean = pd.read_csv(os.path.join(silver_path, latest_dim_file))
        
        # Standardise date formats for temporal join logic
        dim_clean["date_from"] = pd.to_datetime(dim_clean["date_from"]).dt.strftime('%Y-%m-%d')
        dim_clean["date_to"] = pd.to_datetime(dim_clean["date_to"]).dt.strftime('%Y-%m-%d')
    else:
        # If dimension is missing, SK mapping cannot be applied
        dim_clean = None
        print("Warning: No Dimension file found. SK mapping will be skipped.")

    # --------------------------------------------------------------------------------
    # 2. IDENTIFY SCHEDULE FILES (FACT DATA)
    # --------------------------------------------------------------------------------
    # Schedule files contain employee shift allocations per day
    all_files = [f for f in os.listdir(source_path) if f.startswith("Schedules") and f.endswith(".csv")]

    # --------------------------------------------------------------------------------
    # 3. MAIN PROCESSING LOOP (Batch Processing per File)
    # --------------------------------------------------------------------------------
    for file in all_files:

        # Extract file-level date identifier for versioning
        file_date_raw = file.replace("Schedules", "").replace(".csv", "").strip()

        print(f"Processing: {file}")
        file_path = os.path.join(source_path, file)
        df = pd.read_csv(file_path)

        # --------------------------------------------------------------------------------
        # 4. DATA TYPE STANDARDISATION + METADATA ENRICHMENT
        # --------------------------------------------------------------------------------

        # Track ingestion metadata
        df["file_date"] = file_date_raw
        df["load_timestamp"] = datetime.now()

        # Convert shift times to datetime for overlap logic
        df["start_time"] = pd.to_datetime(df["start_time"], errors="coerce")
        df["end_time"] = pd.to_datetime(df["end_time"], errors="coerce")

        # Remove invalid records where time parsing failed
        df = df.dropna(subset=["start_time", "end_time"])

        # --------------------------------------------------------------------------------
        # 5. SHIFT CLEANING LOGIC (OVERLAP REMOVAL / BUSINESS RULE ENFORCEMENT)
        # --------------------------------------------------------------------------------
        # This step ensures:
        # - No overlapping shifts per employee per day
        # - Chronological consistency of schedule records

        df = df.sort_values(["employee_id", "scheduled_date", "start_time", "end_time"])
        clean_rows = []

        # Group by employee and day to enforce intra-day sequencing rules
        for (emp_id, day), group in df.groupby(["employee_id", "scheduled_date"]):
            group = group.sort_values("start_time").copy()

            for i in range(len(group)):
                current_row = group.iloc[i].copy()

                # Compare with previously accepted row
                if i > 0:
                    prev_row = clean_rows[-1]

                    # Ensure same employee and same day before adjusting overlaps
                    if (prev_row["employee_id"] == emp_id and
                        prev_row["scheduled_date"] == day):

                        # Overlap detection condition
                        if prev_row["end_time"] > current_row["start_time"]:
                            
                            # Trim previous shift to avoid overlap
                            prev_row["end_time"] = current_row["start_time"]

                            # Update last stored record
                            clean_rows[-1] = prev_row

                # Append cleaned/current record
                clean_rows.append(current_row)

        clean_df = pd.DataFrame(clean_rows)

        # --------------------------------------------------------------------------------
        # 6. SURROGATE KEY LOOKUP (POINT-IN-TIME DIMENSION JOIN)
        # --------------------------------------------------------------------------------
        # Maps each schedule record to the correct employee version
        # based on effective date range (validity window join)

        if dim_clean is not None:

            # Convert schedule date for SQL comparison
            clean_df["date_sql"] = pd.to_datetime(clean_df["scheduled_date"], dayfirst=True).dt.strftime('%Y-%m-%d')

            # Range join between fact (schedule) and dimension (employee history)
            query = """
            SELECT t.*, dim.sk_employee
            FROM clean_df t
            LEFT JOIN dim_clean dim 
              ON t.employee_id = dim.employee_id
              AND t.date_sql BETWEEN dim.date_from AND dim.date_to
            """

            # Execute SQL join with explicit context
            clean_df = sqldf(query, {"clean_df": clean_df, "dim_clean": dim_clean})

            # Remove helper column used only for join logic
            if "date_sql" in clean_df.columns:
                clean_df = clean_df.drop(columns=["date_sql"])

        # --------------------------------------------------------------------------------
        # 7. OUTPUT TO SILVER LAYER
        # --------------------------------------------------------------------------------
        # Persist cleaned schedules with file-level versioning for traceability

        output_file = os.path.join(silver_path, f"Schedules_{file_date_raw}.csv")
        clean_df.to_csv(output_file, index=False)

        print(f"Successfully saved cleaned schedules: {output_file}")

# %%
base_path = r"C:\CallAgents"
process_schedules_pipeline(base_path)
