# %%
#!/bin/python3
import math
import os
import random
import re
import sys

def ignoreNum(x):
	endString = ''
	for var in x:
		if not var.isdigit(): #Please help check if there are any numbers in the input and ignore them if there are.
			endString += str(var)
		else:
			continue
	return endString

if __name__ == '__main__':
	x=input()
	result = ignoreNum(x)
	print(result)
